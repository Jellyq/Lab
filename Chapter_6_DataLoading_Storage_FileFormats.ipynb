# %%
import pandas as pd
from pandas import Series, DataFrame
import numpy as np

# %% [markdown]
# ## Go to chapter 6 when you need it...

# %%
url = r'C:\Users\Jelly\Desktop\Data\full_buy_train.csv'
# !head C:\Users\Jelly\Desktop\Data\full_buy_train.csv
# Out:
# uid,spu_id,action_type,date,cat_index,goods_index,brand_index
# 372891,858282,1,02-18,30,133420,5281
# 220378,1834930,1,02-21,44,1488110,3136
# 380056,1063802,1,01-03,17,1369257,6471
# 463690,358967,1,03-25,41,143027,55
# 71937,1469563,1,02-16,13,784574,1704
# 204554,2105614,1,03-22,31,1266054,2027
# 152119,1199308,1,01-09,14,1470964,1192
# 536424,1698950,1,02-26,41,1347860,2853
# 413910,798519,1,02-25,41,566151,5258

# %%
df = pd.read_csv(url)
df
# Out:
#            uid   spu_id  action_type   date  cat_index  goods_index  \
# 0       372891   858282            1  02-18         30       133420
# 1       220378  1834930            1  02-21         44      1488110
# 2       380056  1063802            1  01-03         17      1369257
# 3       463690   358967            1  03-25         41       143027
# 4        71937  1469563            1  02-16         13       784574
# 5       204554  2105614            1  03-22         31      1266054
# 6       152119  1199308            1  01-09         14      1470964
# 7       536424  1698950            1  02-26         41      1347860
# 8       413910   798519            1  02-25         41       566151
# 9       290736  1602899            1  02-15         17      1436860
# 10       24017   418363            1  01-03         41      1523819
# 11      566397  1582193            1  02-16          2       981259
# 12      479118   645438            1  02-22         13       437085
# ...

# %%
pd.read_table(url, sep=',')
# Out:
#            uid   spu_id  action_type   date  cat_index  goods_index  \
# 0       372891   858282            1  02-18         30       133420
# 1       220378  1834930            1  02-21         44      1488110
# 2       380056  1063802            1  01-03         17      1369257
# 3       463690   358967            1  03-25         41       143027
# 4        71937  1469563            1  02-16         13       784574
# 5       204554  2105614            1  03-22         31      1266054
# 6       152119  1199308            1  01-09         14      1470964
# 7       536424  1698950            1  02-26         41      1347860
# 8       413910   798519            1  02-25         41       566151
# 9       290736  1602899            1  02-15         17      1436860
# 10       24017   418363            1  01-03         41      1523819
# 11      566397  1582193            1  02-16          2       981259
# 12      479118   645438            1  02-22         13       437085
# ...
